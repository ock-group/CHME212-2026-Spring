# %% [markdown]
# # Homework 00: Practice Submission
#
# **Release Date:** Jan 20
# **Due Date:** Jan 16 11:59 PM
#
# **Total Points:** bonus participation 1%
#
# **Purpose:**
# This is a practice homework to familiarize yourself with:
# - Jupyter notebook environment
# - Running Python code cells
# - Submitting assignments to Gradescope
#
# **Instructions:**
# 1. Complete all problems in this notebook
# 2. Make sure all code cells have been executed
# 3. Save your notebook (File → Save or Ctrl/Cmd + S)
# 4. Submit the .ipynb file to Gradescope
#
# **Note:** This is a low-stakes assignment to help you get comfortable with the submission process!

# %% [markdown]
# ---
# ## Problem 1 – Hello, Chemical Engineering!
#
# Write code to print the message: `"Hello, Chemical Engineering!"`

# %%
# Your solution here

# %% [markdown]
# ---
# ## Problem 2 – Simple Arithmetic
#
# Calculate and print the result of: 42 + 18

# %%
# Your solution here

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting to Gradescope, make sure:
#
# - ✓ All code cells have been executed (you can see the output)
# - ✓ You saved the notebook (File → Save)
# - ✓ Your notebook file has the .ipynb extension
# - ✓ All problems show your work and results
#
# **How to Submit to Gradescope:**
#
# 1. Go to Gradescope and find "Homework 00: Practice Submission"
# 2. Click "Submit" or "Resubmit"
# 3. Upload your `hw00_practice.ipynb` file
# 4. Wait for autograder to run (if enabled)
# 5. Check your score and any feedback
#
# **Note:** You can resubmit as many times as needed before the deadline. Only your latest submission will be graded.
#
# ---
#
# **Point Distribution:**
# - **Participation: bonus 1%**
#
# Good luck with your first submission!
