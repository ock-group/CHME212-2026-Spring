# %% [markdown]
# # CHME 212 — Midterm Exam 1
#
# **Time allowed: 30 minutes**
# **Open notes, closed internet.**
#
# ---
#
# ### Instructions
#
# - Fill in your information in the cell below.
# - For **Part A**, enter your answer (`'a'`, `'b'`, `'c'`, or `'d'`) in each variable.
# - For **Part B**, write your code in the provided code cells.
# - When finished, **restart the kernel and run all cells** to make sure there are no errors.
# - Submit this `.ipynb` file through **Gradescope**.

# %% [markdown]
# ## Student Information

# %%
name  = ""   # Your full name
nuid  = ""   # Your NUID
email = ""   # Your UNL email

# %% [markdown]
# ---
#
# ## Part A — Multiple Choice
#
# Enter your answer as a lowercase letter string: `'a'`, `'b'`, `'c'`, or `'d'`. Adjust the format as needed to match the number of questions on the exam.
#
# ```python
# Qn  = '' # n represents the number
# Q1  = '' # Question 1 example
# ```

# %%
Q1  = ''   # Question 1
Q2  = ''   # Question 2
Q3  = ''   # Question 3
# ...
# Add more questions as needed

# %% [markdown]
# ---
#
# ## Part B — Coding Problem
#
# Read the problem statement from the exam sheet and write your solution in the cells below. Five cells are provided for the tasks. You may rearrange them or solve multiple tasks in a single cell. Just indicate which task(s) the cell addresses in the first line as a comment (e.g., # Task 1, 2).

# %%
# Task 1

# Your code here

# %%
# Task 2 

# Your code here

# %%
# Task 3 

# Your code here

# %%
# Task 4 

# Your code here

# %%
# Task 5

# Your code here
